# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```주로 작성 중인 코드의 끝을 알리는 기호로 사용되며 파이썬에서 한 줄에 작성된 서로 다른 코드를 구분 지을 때 사용할 수 있는 기호를 골라주세요```
#
# 1. ' , ' (쉼표)
# 2. ' + ' (더하기 기호)
# 3. ' ; ' (세미콜론)
# 4. ' / ' (슬래시)

# %% [markdown]
# <span style="color:red">답변</span> :

# %% [markdown]
# 3번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```Python의 PEP 8은 무엇인지 설명하고 PEP 8의 핵심적인 규칙을 1개 이상을 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 핵심적인 규칙은 "들여쓰기"입니다.
#
# 코드 블록은 공백 문자 (스페이스) 네 개로 들여쓰기해야 합니다. 탭(tab) 문자는 사용하지 않습니다.
#
# 각 수준마다 네 개의 공백 문자를 사용하며, 수준이 같은 코드 블록은 동일한 들여쓰기를 사용해야 합니다.
#
# 코드의 구조를 정확히 파악하기 위해 들여쓰기를 올바르게 유지하는 것이 중요합니다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```Python에서 "#"이 의마하는 것은 무엇인지 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 주석을 쓸 때 사용합니다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```Python의 들여쓰기 장점과 기능에 대해 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 들여쓰기를 코드 블록을 구분하는 데 사용합니다.
#
# 장점은 가독성 향상과 일관성을 유지해줍니다. 논리적인 구조를 사용하여 시각적으로 코드를 읽기 쉽게 만듭니다.또한 일관된 코드로 협업을 할때 혼란을 줄이고 일관된 코드를 유지합니다.
#
# 기능은 블록을 구분하여 쉽게 식별 할 수 있고 논리적으로 구조로 만들 수 있게 도움을 줍니다.

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```print( )문의 기능 및 특징에 대해 설명해주세요```

# %% [markdown]
# <span style="color:red">답변</span>

# %%
다양한 데이터 출력이 가능하고 여러개의 값을 출력 할 수 있고

서식을 지정할 수 있고 파일을 출력 할 수 있습니다.

# %% [markdown]
# 다양한 데이터 출력이 가능하고 여러개의 값을 출력 할 수 있고
#
# 서식을 지정할 수 있고 파일을 출력 할 수 있습니다.
